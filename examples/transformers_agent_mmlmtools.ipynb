# %%
from huggingface_hub import login
login('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')
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/yehaochen/.cache/huggingface/token
# Login successful

# %%
from mmlmtools.apis.agents.transformers_agent import load_tools_for_tf_agent
tools = load_tools_for_tf_agent(device='cuda')
# Out:
# [2023-08-16 20:19:08,548] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)

# %%
from transformers import HfAgent
agent = HfAgent("https://api-inference.huggingface.co/models/bigcode/starcoder", additional_tools=tools)

# %%
agent.chat('Please use mmlmtools to generate a picture of an angel')
# Out:
# ==Explanation from the agent==
#
#
#
# ==Code generated by the agent==
# image = mmlmtool_generate_image_from_user_input_text(text)
#
#
# ==Result==
# Evaluation of the code stopped at line 0 before the end because of the following error. Copy paste the following error message and send it back to the agent:
# I get an error: 'The variable `text` is not defined.'

# %%
agent.chat('Please use mmlmtools to detect the face of the above image')
# Out:
# ==Explanation from the agent==
#
#
#
# ==Code generated by the agent==
# image = mmlmtool_human_face_landmark_on_image(image)
#
#
# ==Result==
# Evaluation of the code stopped at line 0 before the end because of the following error. Copy paste the following error message and send it back to the agent:
# I get an error: 'The variable `image` is not defined.'

# %%
agent.chat('Please use mmlmtools to show me the skeleton of the angel in the image')

# %%
agent.chat('Please use mmlmtools to segment the image')

# %%
agent.chat('Please use mmlmtools to convert the text "singe a song" to audio')
# Out:
# ==Explanation from the agent==
# I will use the tool `mmlmtool_text_reader` to convert the text to audio
#
#
# ==Code generated by the agent==
# audio = mmlmtool_text_reader(text="singe a song")
#
#
# ==Result==
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
